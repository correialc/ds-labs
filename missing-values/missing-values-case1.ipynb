# %% [markdown]
# # MISSING DATA

# %% [markdown]
# ## Case 1: [Handling Missing Values in Data](https://medium.com/x8-the-ai-community/handling-missing-values-in-data-54e1dc77e24f) (Prateek Karkare, 2019)

# %%
import pandas as pd
import numpy as py
import matplotlib as plt

# %%
data_full = pd.read_csv("Melbourne_housing_FULL.csv")
data_full.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %% [markdown]
# ### Removing Rows or Columns

# %%
data = data_full.copy()
data.dropna(inplace=True)
data.head()
# Out:
#         Suburb          Address  Rooms Type      Price Method SellerG  \
# 2   Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 4   Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
# 6   Abbotsford      55a Park St      4    h  1600000.0     VB  Nelson
# 11  Abbotsford     124 Yarra St      3    h  1876000.0      S  Nelson
# 14  Abbotsford    98 Charles St      2    h  1636000.0      S  Nelson
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 2   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 4   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 6   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
# 11  7/05/2016       2.5    3067.0  ...       2.0  0.0     245.0         210.0
# 14  8/10/2016       2.5    3067.0  ...       1.0  2.0     256.0         107.0
#
#     YearBuilt         CouncilArea Lattitude  Longtitude  \
# ...

# %%
data = data_full.copy()
data.dropna(inplace=True, axis=1)
data.head()
# Out:
#        Suburb             Address  Rooms Type Method SellerG       Date
# 0  Abbotsford       68 Studley St      2    h     SS  Jellis  3/09/2016
# 1  Abbotsford        85 Turner St      2    h      S  Biggin  3/12/2016
# 2  Abbotsford     25 Bloomburg St      2    h      S  Biggin  4/02/2016
# 3  Abbotsford  18/659 Victoria St      3    u     VB  Rounds  4/02/2016
# 4  Abbotsford        5 Charles St      3    h     SP  Biggin  4/03/2017

# %% [markdown]
# ### Data Inputation

# %%
data = data_full
data['BuildingArea'].fillna(data['BuildingArea'].mean(), inplace=True)
data_full.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0      160.2564
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0      160.2564
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0       79.0000
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0      160.2564
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0      150.0000
#
# ...

# %% [markdown]
# ### Predictive Modeling

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
data = data_full

# Numerical Data Only 
data_selected = data[['Rooms','Bedroom2', 'Bathroom', 'Car', 'Landsize', 'Lattitude', 'Longtitude', 'Propertycount', 'BuildingArea']]
data_selected.head()
# Out:
#    Rooms  Bedroom2  Bathroom  Car  Landsize  Lattitude  Longtitude  \
# 0      2       2.0       1.0  1.0     126.0   -37.8014    144.9958
# 1      2       2.0       1.0  1.0     202.0   -37.7996    144.9984
# 2      2       2.0       1.0  0.0     156.0   -37.8079    144.9934
# 3      3       3.0       2.0  1.0       0.0   -37.8114    145.0116
# 4      3       3.0       2.0  0.0     134.0   -37.8093    144.9944
#
#    Propertycount  BuildingArea
# 0         4019.0      160.2564
# 1         4019.0      160.2564
# 2         4019.0       79.0000
# 3         4019.0      160.2564
# 4         4019.0      150.0000

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(32,10))
plt.title('Correlation of Features', y=1.05, size=15)
sns.heatmap(data_selected.corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-db9bff213a10> in <module>
#       1 colormap = plt.cm.RdBu
# ----> 2 plt.figure(figsize=(32,10))
#       3 plt.title('Correlation of Features', y=1.05, size=15)
#       4 sns.heatmap(data_selected.corr(),linewidths=0.1,vmax=1.0,
#       5             square=True, cmap=colormap, linecolor='white', annot=True)
#
# AttributeError: module 'matplotlib' has no attribute 'figure'

# %%
X = data_selected.values[:,0:5]
y = data_selected.values[:,8].astype('int')

# %%
# evaluate an LDA model on the dataset using k-fold cross validation
model = LinearDiscriminantAnalysis()
kfold = KFold(n_splits=3, random_state=7)
result = cross_val_score(model, X, y, cv=kfold, scoring='accuracy')
model.fit(X,y)
model.predict(X)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py:530: FutureWarning: From version 0.22, errors during fit will result in a cross validation score of NaN by default. Use error_score='raise' if you want an exception raised or error_score=np.nan to adopt the behavior from version 0.22.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-62509e1f9062> in <module>
#       2 model = LinearDiscriminantAnalysis()
#       3 kfold = KFold(n_splits=3, random_state=7)
# ----> 4 result = cross_val_score(model, X, y, cv=kfold, scoring='accuracy')
#       5 model.fit(X,y)
#       6 model.predict(X)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
# ...

# %% [markdown]
# ### Multiple Imputation

# %%
from fancyimpute import IterativeImputer as MICE
# Out:
# Using TensorFlow backend.

# %%
data_fit = pd.DataFrame(MICE().fit_transform(data))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-38a9de2169c7> in <module>
# ----> 1 data_fit = pd.DataFrame(MICE().fit_transform(data))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/impute/_iterative.py in fit_transform(self, X, y)
#     545
#     546         self.initial_imputer_ = None
# --> 547         X, Xt, mask_missing_values = self._initial_imputation(X)
#     548
#     549         if self.max_iter == 0 or np.all(mask_missing_values):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/impute/_iterative.py in _initial_imputation(self, X)
#     474
#     475         X = check_array(X, dtype=FLOAT_DTYPES, order="F",
# --> 476                         force_all_finite=force_all_finite)
#     477         _check_inputs_dtype(X, self.missing_values)
#     478
#
# ...
